# %% [markdown]
# # Train Hand Digit Model on Google Colab
# Since you opened this notebook directly from GitHub, Colab only loaded this specific file. We need to clone the rest of the repository to get your dataset and Python scripts.
#
# 1. Go to **Runtime > Change runtime type** and select **T4 GPU**.
# 2. Run the cells below.

# %%
# Clone the repository to get main.py, dataset_loader.py, and your dataset
# !git clone https://github.com/adityaB-code100/handwritten-Digit

# Change directory to the training folder
import os

# Go to correct folder
os.chdir('/content/handwritten-Digit/digit_model_training')

# Check current path
# !pwd
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 import os
#       7 # Go to correct folder
# ----> 8 os.chdir('/content/handwritten-Digit/digit_model_training')
#      10 # Check current path
#      11 get_ipython().system('pwd')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/content/handwritten-Digit/digit_model_training'

# %%
# Install dependencies
# !pip install -r requirements.txt

# %%
# Start the training pipeline!
import os

print(os.listdir('/content/handwritten-Digit/caps')[:20])
# !python main.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Start the training pipeline!
#       2 import os
# ----> 4 print(os.listdir('/content/handwritten-Digit/caps')[:20])
#       5 get_ipython().system('python main.py')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/content/handwritten-Digit/caps'

# %% [markdown]
# ### Save your models to Google Drive
# Colab deletes all files when you close the tab. Run this cell after training to save your newly trained models securely to your Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

import shutil
# !mkdir -p '/content/drive/MyDrive/Hand_Digit_Models'
shutil.copytree('/content/hand-Digit/digit_model_training/saved_models', '/content/drive/MyDrive/Hand_Digit_Models', dirs_exist_ok=True)
print("Models successfully saved to your Google Drive!")
